# %%
import pandas as pd

# %%
# Load Data 

df=pd.read_csv("Google_data.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.tail(30)
# Out:
#                                                  App             Category  \
# 10811                                    FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                  Fr Agnel Pune               FAMILY
# 10813                                 DICT.fr Mobile             BUSINESS
# 10814                           FR: My Secret Pets!                FAMILY
# 10815                      Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                             FieldBi FR Offline             BUSINESS
# 10817                           HTC Sense Input - FR                TOOLS
# 10818                           Gold Quote - Gold.fr              FINANCE
# 10819                                      Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                Fr. Daoud Lamei               FAMILY
# 10821                                        Poop FR               FAMILY
# 10822                                      PLMGSS FR         PRODUCTIVITY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
missing_value=df.isnull().sum()
missing_value
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
mean_value=df["Rating"].mean()
df["Rating"].fillna(mean_value, inplace=True)

# %%
df.describe()
# Out:
#              Rating
# count  10841.000000
# mean       4.193338
# std        0.499557
# min        1.000000
# 25%        4.100000
# 50%        4.200000
# 75%        4.500000
# max       19.000000

# %%
df.describe().T
# Out:
#           count      mean       std  min  25%  50%  75%   max
# Rating  10841.0  4.193338  0.499557  1.0  4.1  4.2  4.5  19.0

# %%
df.describe(include="object")
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2784          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df.dropna(subset=['Category'], inplace=True)

# %%
# Is there any invalid Category

import numpy as np
unique='ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY','BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION','DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE','FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME','LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL','SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL','TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER','VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION','1.9'
df['Category']=df['Category'].apply(lambda x:x if x in  unique else np.nan)
df['Category'].unique()
df.dropna(subset=['Category'], inplace=True)
df.Category.isnull().sum()
# Out:
# 0

# %%
df.Rating.isnull().sum()
# Out:
# 0

# %%
df.Rating.value_counts()
# Out:
# Rating
# 4.193338     1465
# 4.400000     1032
# 4.300000     1016
# 4.500000      977
# 4.200000      888
# 4.600000      768
# 4.100000      657
# 4.000000      539
# 4.700000      484
# 3.900000      372
# 3.800000      293
# 5.000000      271
# 3.700000      231
# 4.800000      228
# 3.600000      169
# 3.500000      157
# 3.400000      127
# 3.300000      101
# 4.900000       87
# 3.000000       82
# 3.100000       69
# 3.200000       64
# 2.900000       45
# 2.800000       40
# 2.600000       24
# 2.700000       23
# 2.500000       20
# 2.300000       20
# 2.400000       19
# 1.000000       16
# 2.200000       14
# 1.900000       12
# 2.000000       12
# 1.700000        8
# 1.800000        8
# 2.100000        8
# 1.600000        4
# 1.400000        3
# 1.500000        3
# 1.200000        1
# 19.000000       1
# Name: count, dtype: int64

# %%
df['Rating_category']=df['Rating'].apply(lambda x:"High" if x>3.5 else"Low")

# %%
df['Rating_category'].value_counts()
# Out:
# Rating_category
# High    9478
# Low      880
# Name: count, dtype: int64

# %%
# !pip install numpy

# %%
# package
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data set
data=pd.read_csv("Google_data.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Distribution app rating
import seaborn as sns 
import matplotlib.pyplot as plt
data=pd.read_csv("Google_data.csv")
plt.figure(figsize=(10,6))
sns.histplot(data['Rating'].dropna(),kde=True,bins=20,color='skyblue')
plt.title('Distribution App Rating')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot App Rating
plt.figure(figsize=(10,6))
sns.boxplot(x='Rating',data=data,color='lightgreen')
plt.title('Boxplot App Rating')
plt.xlabel('Rating')
plt.show()

# %%
import numpy as np
data['Rating']=np.log1p(data['Rating'])

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Rating',data=data,color='lightgreen')
plt.title('Boxplot App Rating')
plt.xlabel('Rating')
plt.show()

# %%
Q1=data['Rating'].quantile(0.25)
Q2=data['Rating'].quantile(0.50)
Q3=data['Rating'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q1+1.5*IQR

# %%
filterdata=data[(data['Rating']>=lower_bound)&(data['Rating']<=upper_bound)]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Rating',data=filterdata,color='lightgreen')
plt.title('Boxplot App Rating')
plt.xlabel('Rating')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.countplot(y='Category',data=data,order=data['Category'].value_counts().index,palette='viridis',hue='Category')
plt.title('Count of Apps By Category')
plt.xlabel('Count')
plt.ylabel('Category')
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Google_data.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
 #There are unique values in the size column are['160k','98M','Varies with device']. We have to first make the unit into one common unit from M and k to bytes. and then remove the M and k from  the values and convert them into numeric data type

# %%
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 8829

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 316

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 1695

# %%
df['Size'].value_counts().sum()
# Out:
# 10841

# %%
# 8829+316+1695 = 10841

# %%
# Converting Size column function
def convert_size(Size):
    ''' This function will convert the size column to numeric by multiplying the values with 1024
    if it has 'k' in it and 1024*1024 if it has 'M' in it.'''
    if convert_to_bytes(Size_str):
        if 'k' in Size:
            return float(Size.replace('k',' '))*1000
        elif 'M' in Size:
            return float(Size.replace('M',' '))*1000000
        elif 'varies with device' in Size:
            return np.nan
    return(Size)
df.rename(columns={'Size':'Size_in_bytes'}, inplace=True)
df['Size_in_bytes'] =df['Size_in_bytes'].apply(convert_to_bytes)
df['Size_in_bytes'] =pd.to_numeric(df['Size_in_bytes'], errors='coerce')
df

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0     159     19000000.0      10,000+  Free     0       Everyone
# 1     967     14000000.0     500,000+  Free     0       Everyone
# 2   87510      8700000.0   5,000,000+  Free     0       Everyone
# 3  215644     25000000.0  50,000,000+  Free     0           Teen
# 4     967      2800000.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Free                 1
# Name: count, dtype: int64

# %%
df['Installs'].loc[df['Installs'].str.contains('\+')].value_counts().sum()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\+'
# <>:1: SyntaxWarning: invalid escape sequence '\+'
# C:\Users\hp\AppData\Local\Temp\ipykernel_4820\2827484067.py:1: SyntaxWarning: invalid escape sequence '\+'
#   df['Installs'].loc[df['Installs'].str.contains('\+')].value_counts().sum()
# 10839

# %%
df['Installs'].value_counts().sum()
# Out:
# 10841

# %%
# The only problem i see here is the + sign in the values, lets remove them and convert the column into numeric data type
# There are no null values in the installs column
# However, one value 0 has no pluse sign 
# Lets remove the + and , from the values and convert them into numeric data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size_in_bytes   9145 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
# Convert 'Installs' column to string_type
df['Installs']=df['Installs'].astype(str)

# Remove non-numeric values('Free') from the 'Installs' column
df['Installs']=df['Installs'].apply(lambda x:x.replace('Free','0') if 'Free' in x else x)

# Remove the '+' character from the values
df['Installs']=df['Installs'].apply(lambda x:x.replace('+',''))

# Remove commas from the 'Installs' values
df['Installs']=df['Installs'].str.replace(',','')

# Convert 'Installs' values to integers
df['Installs']=df['Installs'].astype(int)

# %%
# Removing + from Installs value
df['Installs']=df['Installs'].apply(lambda x:x.replace('+','') if '+' in str(x) else x)
df['Installs']=df['Installs'].apply(lambda x:x.replace(',','') if ',' in str(x) else x)
df['Installs']=df['Installs'].apply(lambda x: int(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size_in_bytes   9145 non-null   float64
#  5   Installs        10841 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               16
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size_in_bytes  Installs  Type Price Content Rating  \
# 0     159     19000000.0     10000  Free     0       Everyone
# 1     967     14000000.0    500000  Free     0       Everyone
# 2   87510      8700000.0   5000000  Free     0       Everyone
# 3  215644     25000000.0  50000000  Free     0           Teen
# 4     967      2800000.0    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df['Installs'].dtype
# Out:
# dtype('int64')

# %%
# Making a new column called 'Installs_category' which will have the category of the installs
bins=[-1,0,10,1000,10000,100000,1000000,10000000,100000000]
labels=['no','Very Low','Low','Moderate','More than moderate','High','Very High','Top Notch']
df['Installs_category']=pd.cut(df['Installs'],bins=bins,labels=labels)

# %%
df['Installs_category'].value_counts()
# Out:
# Installs_category
# Low                   2161
# High                  2118
# Very High             2004
# More than moderate    1648
# Moderate              1531
# Top Notch              698
# Very Low               535
# no                      16
# Name: count, dtype: int64

# %%
# Lets have a look on the Price column

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $1.75         1
# $14.00        1
# $4.85         1
# $46.99        1
# $1.04         1
# Name: count, Length: 93, dtype: int64

# %%
df['Price']=df['Price'].apply(lambda x:x.replace('Everyone','0') if 'Everyone' in str(x) else x)

# Remove the dollar sign from the values
df['Price']=df['Price'].apply(lambda x:x.replace('$',''))

# Convert 'Price' values to float
df['Price']=df['Price'].astype(float)

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %%
# Use f string to print min, max, average of price
print(f"Min price is :{df['Price'].min()}$")
print(f"Max price is :{df['Price'].max()}$")
print(f"Average price is :{df['Price'].mean()}$")
# Out:
# Min price is :0.0$
# Max price is :400.0$
# Average price is :1.0272733142699015$

# %%
df.describe()
# Out:
#             Rating  Size_in_bytes      Installs         Price
# count  9367.000000   9.145000e+03  1.084100e+04  10841.000000
# mean      4.193338   2.151653e+07  1.546291e+07      1.027273
# std       0.537431   2.258875e+07  8.502557e+07     15.948971
# min       1.000000   8.500000e+03  0.000000e+00      0.000000
# 25%       4.000000   4.900000e+06  1.000000e+03      0.000000
# 50%       4.300000   1.300000e+07  1.000000e+05      0.000000
# 75%       4.500000   3.000000e+07  5.000000e+06      0.000000
# max      19.000000   1.000000e+08  1.000000e+09    400.000000

# %%
df.isnull().sum()
# Out:
# App                     0
# Category                0
# Rating               1474
# Reviews                 0
# Size_in_bytes        1696
# Installs                0
# Type                    1
# Price                   0
# Content Rating          1
# Genres                  0
# Last Updated            0
# Current Ver             8
# Android Ver             3
# Installs_category     130
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1696
# Rating               1474
# Installs_category     130
# Current Ver             8
# Android Ver             3
# Type                    1
# Content Rating          1
# App                     0
# Category                0
# Reviews                 0
# Installs                0
# Price                   0
# Genres                  0
# Last Updated            0
# dtype: int64

# %%
# Total number of null values in dataframe
df.isnull().sum().sum()
# Out:
# 3313

# %%
# Percentage of missing values in each column
(df.isnull().sum() / len(df)*100).sort_values(ascending=False)
# Out:
# Size_in_bytes        15.644313
# Rating               13.596532
# Installs_category     1.199151
# Current Ver           0.073794
# Android Ver           0.027673
# Type                  0.009224
# Content Rating        0.009224
# App                   0.000000
# Category              0.000000
# Reviews               0.000000
# Installs              0.000000
# Price                 0.000000
# Genres                0.000000
# Last Updated          0.000000
# dtype: float64

# %%
# Lets plot missing values in dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# There is the another way. lets plot the missing values by percentage

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
missing_percentage=df.isnull().sum() / len(df) * 100
missing_percentage.plot(kind='bar')
plt.title('Percentage of missing values in each column')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.show()

# %%
plt.figure(figsize=(16,6))
missing_percentage[missing_percentage < 1].plot(kind='bar')
plt.title('Percentage of missing values in each column')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1696
# Rating               1474
# Installs_category     130
# Current Ver             8
# Android Ver             3
# Type                    1
# Content Rating          1
# App                     0
# Category                0
# Reviews                 0
# Installs                0
# Price                   0
# Genres                  0
# Last Updated            0
# dtype: int64

# %%
# We have 1695 missing values in the 'Size_in_bytes' column, which is 15.6% of the total values in the column.
# We have 1474 missing values in the 'Rating; column which is 13.6% of the total values in the column.
# We have 8 missing value in the 'Current Ver' column, which is 0.07% of the total values in the column.
# We have 2 missing values in the 'Android Ver' column, which is 0.01% of the total values in the column.
# We have only 1 missing values in Category, Type and genres columns, which is 0.009% of the total values in the column.

# %%
df['Reviews'] = df['Reviews'].replace('NaN', None)  # Replace 'NaN' string with actual None
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')
df['Reviews'] = df['Reviews'].astype(float)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Reviews'].dtype
# Out:
# dtype('float64')

# %%
plt.figure(figsize=(16,10))
numeric_cols=['Rating','Reviews','Size_in_bytes','Installs','Price']
sns.heatmap(df[numeric_cols].corr(),annot=True)
# Out:
# <Axes: >

# %%
df[numeric_cols].corr()
# Out:
#                  Rating   Reviews  Size_in_bytes  Installs     Price
# Rating         1.000000  0.068141       0.083734  0.048652 -0.021176
# Reviews        0.068141  1.000000       0.238215  0.643122 -0.009667
# Size_in_bytes  0.083734  0.238215       1.000000  0.164787 -0.023006
# Installs       0.048652  0.643122       0.164787  1.000000 -0.011688
# Price         -0.021176 -0.009667      -0.023006 -0.011688  1.000000

# %%
# We can calculate the person correlation coefficient using scipy as follows
from scipy import stats
df_clean=df.dropna()
pearson_r,_=stats.pearsonr(df_clean['Reviews'],df_clean['Installs'])
print(f"pearson's R between Rating and Installs is {pearson_r:4f}")
# Out:
# pearson's R between Rating and Installs is 0.619392

# %%
#OBSERVATION
#lighter color shows high corrleation and darker color shows low correlation
#We can see Reviews column has high correlation with Installs column, which is 0.62 according to corr()

# %%
# Before going ahead, lets remove the rows with missing values in the Current Ver, Android Ver, Category, Types and genres columns, as they are very less in number and will not affect our analysis.

# %%
print(f"The length of the dataframe before removing null values is :{len(df)}")
# Out:
# The length of the dataframe before removing null values is :10841

# %%
# Rmove the rows having null values in the 'Current Ver','Android Ver','Category','Type' and 'Genres' column
df.dropna(subset=['Current Ver','Android Ver','Category','Type','Genres'], inplace=True)

# %%
print(f"The length of the dataframe after removing null values is :{len(df)}")
# Out:
# The length of the dataframe after removing null values is :10829

# %%
# We removed 12 rows having null values in the Current Ver, Android Ver, Category, Types and genres columns.

# %%
# Lets check the null values again
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1694
# Rating               1469
# Installs_category     130
# App                     0
# Category                0
# Reviews                 0
# Installs                0
# Type                    0
# Price                   0
# Content Rating          0
# Genres                  0
# Last Updated            0
# Current Ver             0
# Android Ver             0
# dtype: int64

# %%
df.groupby('Installs_category')['Rating'].describe()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4820\520456251.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Installs_category')['Rating'].describe()
#                      count      mean       std  min  25%  50%  75%  max
# Installs_category
# no                     0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Very Low              81.0  4.637037  0.845199  1.0  4.8  5.0  5.0  5.0
# Low                 1278.0  4.170970  0.825605  1.0  3.8  4.4  4.8  5.0
# Moderate            1440.0  4.035417  0.604428  1.4  3.8  4.2  4.5  5.0
# More than moderate  1616.0  4.093255  0.505619  1.6  3.9  4.2  4.5  4.9
# High                2113.0  4.207525  0.376594  1.8  4.0  4.3  4.5  4.9
# Very High           2004.0  4.287076  0.294902  2.0  4.1  4.3  4.5  4.9
# ...

# %%
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Low                   880
# Very Low              453
# Moderate               88
# More than moderate     31
# no                     14
# High                    3
# Very High               0
# Top Notch               0
# Name: count, dtype: int64

# %%
df['Rating']=df.groupby('Installs_category')['Rating'].transform(lambda x: x.fillna(x.mean()))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4820\1894478187.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['Rating']=df.groupby('Installs_category')['Rating'].transform(lambda x: x.fillna(x.mean()))

# %%
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# no                    14
# Very Low               0
# Low                    0
# Moderate               0
# More than moderate     0
# High                   0
# Very High              0
# Top Notch              0
# Name: count, dtype: int64

# %%
#plot the boxplot of the Rating in each Installs_Category
plt.figure(figsize=(16,6))# make figure size
sns.boxplot(x='Installs_category',y='Rating',hue='Installs_category',data=df)# plot the boxplot
# add the text of number of null_values in each category
plt.text(0, 3.5, 'Null values: 14')
plt.text(1, 3.5, 'Null values: 874')
plt.text(2, 3.5, 'Null values: 86')
plt.text(3, 3.5, 'Null values: 31')
plt.text(4, 3.5, 'Null values: 3')
plt.text(5, 3.5, 'Null values: 0')
plt.text(6, 3.5, 'Null values: 0')
plt.text(7, 3.5, 'Null values: 0')
# Out:
# Text(7, 3.5, 'Null values: 0')

# %%
df['Installs_category'].loc[df['Reviews'].isnull()].value_counts()
# Out:
# Installs_category
# no                    0
# Very Low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %%
# There are no null values in Review

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x='Installs_category', y='Reviews', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %%
# The data looks really imbalance, lets normalize the data using log transformation

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x='Installs_category', y=np.log10(df['Reviews']), data=df)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %%
# We also draw the scalar plot of the Rating and Reviews columns with the Installs column

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x='Rating', y='Reviews',hue='Installs_category',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
# It doesn't show any trend because, you should know that Rating is a categorial variable and Reviews is a continous variable, therefore we can not plot them together
# Let's try with Reviews and Installs

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x='Reviews', y='Installs',data=df)
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %%
# Try log transformation

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x=np.log10(df['Reviews']),y=np.log10(df['Installs']), data=df)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %%
# Let's plot a line plot to see the trend

# %%
plt.figure(figsize=(16,6))
sns.lmplot(x='Reviews', y='Installs',data=df)

# %%
# Here, we can see a nice trend, Which shows that number of Reviews increases with the number of Installs,Which is quite obvious.

# %%
df.isnull().sum()
# Out:
# App                     0
# Category                0
# Rating                144
# Reviews                 0
# Size_in_bytes        1694
# Installs                0
# Type                    0
# Price                   0
# Content Rating          0
# Genres                  0
# Last Updated            0
# Current Ver             0
# Android Ver             0
# Installs_category     130
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 483

# %%
# Find duplicate if any in the app column
df['App'].duplicated().sum()
# Out:
# 1181

# %%
# Which Category has the highest number of Apps
df['Category'].value_counts().head(10)
# Out:
# Category
# FAMILY             1968
# GAME               1144
# TOOLS               841
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     390
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: count, dtype: int64

# %%
# Which Category has the highest number of Installs
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  35086024415
# COMMUNICATION         32647276251
# PRODUCTIVITY          14176091369
# SOCIAL                14069867902
# TOOLS                 11452271905
# FAMILY                10258203405
# PHOTOGRAPHY           10088247655
# NEWS_AND_MAGAZINES     7496317760
# TRAVEL_AND_LOCAL       6868887146
# VIDEO_PLAYERS          6222002720
# Name: Installs, dtype: int64

# %%
# Which Category has the highest number of Reviews
df.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME               1.585422e+09
# COMMUNICATION      8.154623e+08
# SOCIAL             6.212414e+08
# FAMILY             4.102261e+08
# TOOLS              2.731810e+08
# PHOTOGRAPHY        2.135166e+08
# SHOPPING           1.150412e+08
# PRODUCTIVITY       1.141170e+08
# VIDEO_PLAYERS      1.103802e+08
# PERSONALIZATION    8.934572e+07
# Name: Reviews, dtype: float64

# %%
# Which Category has the highest Rating
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# EVENTS                 4.394346
# EDUCATION              4.387136
# ART_AND_DESIGN         4.367122
# BOOKS_AND_REFERENCE    4.359309
# PERSONALIZATION        4.335039
# HEALTH_AND_FITNESS     4.286207
# GAME                   4.284513
# SOCIAL                 4.262375
# SHOPPING               4.260600
# PARENTING              4.259759
# Name: Rating, dtype: float64

# %%
# Which is range of Rating in most of apps
plt.figure(figsize=(16,6))
sns.kdeplot(df['Rating'],color='blue',fill=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
# Which type has the highest Installs
plt.figure(figsize=(16,6))
sns.barplot(x='Type',y='Installs',data=df)
# Out:
# <Axes: xlabel='Type', ylabel='Installs'>

# %%
# Which Price has the highest Installs
plt.figure(figsize=(16,6))
sns.scatterplot(x='Installs',y='Price',hue='Type',data=df)
# Out:
# <Axes: xlabel='Installs', ylabel='Price'>

# %%
# Which Installs Category has the average sizd
plt.figure(figsize=(16,6))
sns.barplot(x='Installs_category',y='Size_in_bytes',data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Size_in_bytes'>

# %%
# Which App's has the most highest content Rating
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8704
# Teen               1208
# Mature 17+          499
# Everyone 10+        413
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
# Plot the bar plot of Content Rating vs Installs
plt.figure(figsize=(16,6))
sns.barplot(x='Content Rating',y='Installs',data=df)
# Out:
# <Axes: xlabel='Content Rating', ylabel='Installs'>

# %%
# Which Category the content rating for evryone
df['Category'].loc[df['Content Rating']=='Everyone'].value_counts()
# Out:
# Category
# FAMILY                 1526
# TOOLS                   833
# GAME                    608
# BUSINESS                445
# MEDICAL                 442
# PRODUCTIVITY            413
# FINANCE                 361
# LIFESTYLE               345
# COMMUNICATION           345
# SPORTS                  338
# PERSONALIZATION         320
# PHOTOGRAPHY             318
# HEALTH_AND_FITNESS      307
# TRAVEL_AND_LOCAL        251
# SHOPPING                208
# BOOKS_AND_REFERENCE     201
# NEWS_AND_MAGAZINES      169
# VIDEO_PLAYERS           146
# EDUCATION               144
# MAPS_AND_NAVIGATION     133
# FOOD_AND_DRINK          117
# SOCIAL                  101
# HOUSE_AND_HOME           86
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        83
# WEATHER                  78
# ART_AND_DESIGN           60
# PARENTING                58
# EVENTS                   53
# BEAUTY                   45
# ENTERTAINMENT            39
# COMICS                   26
# ...

# %%
# Plot top 5 Rated paid apps
plt.figure(figsize=(16,6))
sns.barplot(x='App',y='Rating',data=df[df['Type']=='Paid'].sort_values(by='Rating',ascending=False).head(5))
# Out:
# <Axes: xlabel='App', ylabel='Rating'>

# %%
df[df['Type']== 'Paid'].sort_values(by='Rating',ascending=False).head(5)
# Out:
#                                                     App             Category  \
# 5966                                       BC MVA Fines  BOOKS_AND_REFERENCE
# 3957                                       ADS-B Driver                TOOLS
# 7466                                             211:CK                 GAME
# 7377                              CI 174 Gray Icon Pack      PERSONALIZATION
# 8018  30WPM Amateur ham radio Koch CW Morse code tra...               FAMILY
#
#       Rating  Reviews  Size_in_bytes  Installs  Type  Price Content Rating  \
# 5966     5.0      5.0      7200000.0        50  Paid   1.75       Everyone
# 3957     5.0      2.0      6300000.0       100  Paid   1.99       Everyone
# 7466     5.0      8.0     38000000.0        10  Paid   0.99           Teen
# 7377     5.0      1.0     46000000.0        10  Paid   0.99       Everyone
# 8018     5.0      1.0      3700000.0        10  Paid   1.49       Everyone
#
# ...

# %%
# plot top 5 Rated free Apps
plt.figure(figsize=(16,6))
sns.barplot(x='App',y='Rating',data=df[df['Type']=='Free'].sort_values(by='Rating',ascending=False).head(5))
# Out:
# <Axes: xlabel='App', ylabel='Rating'>

# %%
df[df['Type']== 'Free'].sort_values(by='Rating',ascending=False).head(5)
# Out:
#                                                    App        Category  \
# 8888           Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 5064  Tafsiir Quraan MP3 Af Soomaali Quraanka Kariimka       LIFESTYLE
# 7139                                       CB Register          FAMILY
# 7142                                        Cb browser   COMMUNICATION
# 7147                                         CB Heroes          SOCIAL
#
#       Rating  Reviews  Size_in_bytes  Installs  Type  Price Content Rating  \
# 8888     5.0      1.0      2900000.0       100  Free    0.0       Everyone
# 5064     5.0      7.0      3400000.0      1000  Free    0.0       Everyone
# 7139     5.0      1.0      5600000.0        10  Free    0.0       Everyone
# 7142     5.0      5.0      3700000.0        50  Free    0.0       Everyone
# 7147     5.0      5.0      1800000.0         5  Free    0.0       Everyone
#
#              Genres    Last Updated Current Ver Android Ver Installs_category
# ...

# %%
# Plot top 5 FREE apps with highest number of Reviews
plt.figure(figsize=(16,6))
sns.barplot(x='App',y='Reviews',data=df[df['Type']=='Free'].sort_values(by='Reviews',ascending=False).head(5))
# Out:
# <Axes: xlabel='App', ylabel='Reviews'>

# %%
# Plot top 5 PAID apps with highest number of Reviews
plt.figure(figsize=(16,6))
sns.barplot(x='App',y='Reviews',data=df[df['Type']=='Paid'].sort_values(by='Reviews',ascending=False).head(5))
# Out:
# <Axes: xlabel='App', ylabel='Reviews'>
